# %%
import os
import sys
import time
import numpy as np
import pandas as pd
import sklearn
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf

# %%
(x_train_all,y_train_all),(x_test,y_test) = tf.keras.datasets.fashion_mnist.load_data()
#(x_valid,y_valid)验证集，训练集（x_train,y_train）
x_valid, x_train = x_train_all[:10000], x_train_all[10000:]
y_valid, y_train = y_train_all[:10000], y_train_all[10000:]
print(x_valid.shape,y_valid.shape)
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
print(np.max(x_train),np.min(x_valid))
# Out:
# (10000, 28, 28) (10000,)
# (50000, 28, 28) (50000,)
# (10000, 28, 28) (10000,)
# 255 0

# %%
#归一化
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
#sklearn 接受二维数组
#用于改变数组的形状，reshape(-1,1) -1表示任意行（原来是多少就是多少）
x_train_scaled = scaler.fit_transform(x_train.astype(np.float32).reshape(-1,1)).reshape(-1,28,28)
x_valid_scaled = scaler.transform(x_valid.astype(np.float32).reshape(-1,1)).reshape(-1,28,28)
x_test_scaled = scaler.transform(x_test.astype(np.float32).reshape(-1,1)).reshape(-1,28,28)

# %%
print(np.max(x_train_scaled),np.min(x_valid_scaled))
# Out:
# 2.0237024 -0.8105628

# %%
def show_single_image(img_arr):
    plt.imshow(img_arr,cmap="binary")
    plt.show()
show_single_image(x_train[0])
def show_imgs(n_rows,n_cols,x_data,y_data,class_names):
    assert len(x_data) == len(y_data) #断言 ，表达式为False发生异常
    assert n_rows*n_cols < len(x_data)
    plt.figure(figsize = (n_cols*2,n_rows*2))#设置画布的宽高
    for row in range(n_rows):
        for col in range(n_cols):
            index = n_cols * row + col
            plt.subplot(n_rows,n_cols,index+1)
            plt.imshow(x_data[index],cmap="binary",interpolation="nearest") #interpolation图像插值，nearest放大小图像效果好
            plt.axis("off")
            plt.title(class_names[y_data[index]])
    plt.show()
class_names = ["T-shirt","Trouser","pullover","Dress","Coat","Sandal","shirt","Sneaker","Bag","Ankle boot"]
show_imgs(3,5,x_train,y_train,class_names)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=[28,28]),
    tf.keras.layers.Dense(300,activation="relu"),
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(10,activation="softmax")
]
)
#relu: y = max(0,x) 
#sortmax: x = [x1,x2,...,xn] , #y = [e^x1/sum,e^x2/sum,...,e^xn/sum] ,sum = e^x1+e^x2+...+e^xn
model.compile(optimizer='dam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.core.Flatten at 0x1b7ca630>,
#  <tensorflow.python.keras.layers.core.Dense at 0x1b7ca518>,
#  <tensorflow.python.keras.layers.core.Dense at 0x1b7ca2b0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x1b7ca0f0>]

# %%
model.summary()
print(x_train.shape,y_train.shape)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 300)               235500
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________
# (55000, 28, 28) (55000,)

# %%
#Tensorboard, earlystopping,ModelCheckpoint
logdir = "./callbacks"
if not os.path.exists(logdir):
    os.mkdir(logdir)
output_model_file = os.path.join(logdir,"fashion_mnist_model.h5")
callbacks = [
    tf.keras.callbacks.TensorBoard(logdir),
    tf.keras.callbacks.ModelCheckpoint(output_model_file,save_best_only = True),
    #被监测量改变小于min_delta或者patience次没有得到改进
    tf.keras.callbacks.EarlyStopping(patience= 5,min_delta = 1e-3),
    
]

# %%
# 输入长度784的向量 -> 经过第一个300个神经元的全连接层 w1 = [784,300]，b1 = [300,] 通过relu得到一个长度为300的输出向量
#->经过第二个100个神经元的全连接层 w2 = [300,100],b2 = [100,] 通过relu得到 一个长度为100的输出向量
#->经过第三个10个神经元的全连接层 w2 = [100,10], b3 = [10,] 通过softmax得到 一个长度为10的输出向量
history = model.fit(x_train_scaled,y_train,epochs=10,validation_data = (x_valid_scaled,y_valid))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# WARNING:tensorflow:Trace already enabled
#    32/50000 [..............................] - ETA: 48s - loss: 1.6767 - accuracy: 0.5312WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
#    32/50000 [..............................] - ETA: 3:12 - loss: 1.6767 - accuracy: 0.5312
# ---------------------------------------------------------------------------
# ProfilerNotRunningError                   Traceback (most recent call last)
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_start(self, model, callbacks, use_samples, verbose, mode)
#     752     try:
# --> 753       yield
#     754       model._successful_loop_finish = True
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     180       cbks.make_logs(model, batch_logs, batch_outs, mode)
# --> 181       step += 1
#     182
#
# G:\anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_batch(self, step, mode, size)
#     787           self.callbacks._call_batch_hook(
# --> 788               mode, 'end', step, batch_logs)
#     789           self.progbar.on_batch_end(step, batch_logs)
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     238       batch_hook = getattr(callback, hook_name)
# --> 239       batch_hook(batch, logs)
#     240     self._delta_ts[hook_name].append(time.time() - t_before_callbacks)
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1694       if self._is_tracing:
# -> 1695         self._log_trace()
#    1696       elif (not self._is_tracing and
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _log_trace(self)
#    1746             step=step,
# -> 1747             profiler_outdir=os.path.join(self._log_write_dir, 'train'))
#    1748       self._is_tracing = False
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\ops\summary_ops_v2.py in trace_export(name, step, profiler_outdir)
#    1239   if profiler:
# -> 1240     _profiler.save(profiler_outdir, _profiler.stop())
#    1241
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\eager\profiler.py in stop()
#      98       raise ProfilerNotRunningError(
# ---> 99           'Cannot stop profiling. No profiler is running.')
#     100     if context.default_execution_mode == context.EAGER_MODE:
#
# ProfilerNotRunningError: Cannot stop profiling. No profiler is running.
#
# During handling of the above exception, another exception occurred:
#
# ProfilerNotRunningError                   Traceback (most recent call last)
# <ipython-input-66-e31a02c61e0d> in <module>
#       2 #->经过第二个100个神经元的全连接层 w2 = [300,100],b2 = [100,] 通过relu得到 一个长度为100的输出向量
#       3 #->经过第三个10个神经元的全连接层 w2 = [100,10], b3 = [10,] 通过softmax得到 一个长度为10的输出向量
# ----> 4 history = model.fit(x_train_scaled,y_train,epochs=10,validation_data = (x_valid_scaled,y_valid),callbacks=callbacks)
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# G:\anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_start(self, model, callbacks, use_samples, verbose, mode)
#     755     finally:
#     756       # End of all epochs
# --> 757       self.callbacks._call_end_hook(mode)
#     758
#     759   @tf_contextlib.contextmanager
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _call_end_hook(self, mode)
#     260     """Helper function for on_{train|test|predict}_end methods."""
#     261     if mode == ModeKeys.TRAIN:
# --> 262       self.on_train_end()
#     263     elif mode == ModeKeys.TEST:
#     264       self.on_test_end()
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_train_end(self, logs)
#     377     """
#     378     for callback in self.callbacks:
# --> 379       callback.on_train_end(logs)
#     380
#     381   def on_test_begin(self, logs=None):
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_train_end(self, logs)
#    1718   def on_train_end(self, logs=None):
#    1719     if self._is_tracing:
# -> 1720       self._log_trace()
#    1721     self._close_writers()
#    1722
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _log_trace(self)
#    1745             name='batch_%d' % step,
#    1746             step=step,
# -> 1747             profiler_outdir=os.path.join(self._log_write_dir, 'train'))
#    1748       self._is_tracing = False
#    1749
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\ops\summary_ops_v2.py in trace_export(name, step, profiler_outdir)
#    1238
#    1239   if profiler:
# -> 1240     _profiler.save(profiler_outdir, _profiler.stop())
#    1241
#    1242   trace_off()
#
# G:\anaconda3\lib\site-packages\tensorflow_core\python\eager\profiler.py in stop()
#      97     if _profiler is None:
#      98       raise ProfilerNotRunningError(
# ---> 99           'Cannot stop profiling. No profiler is running.')
#     100     if context.default_execution_mode == context.EAGER_MODE:
#     101       context.context().executor.wait()
#
# ProfilerNotRunningError: Cannot stop profiling. No profiler is running.

# %%
def plot_learning_curves(history,img_title):
    pd.DataFrame(history.history).plot(figsize = (8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    from matplotlib.font_manager import FontProperties
    font_set= FontProperties(fname=r"c:\windows\fonts\simsun.ttc",size=12)
    plt.title(img_title,fontProperties = font_set)
    plt.show()
plot_learning_curves(history,"归一化后的训练结果（sgd）")

# %%
plot_learning_curves(history,"归一化后的训练结果（Aadm)")

# %%
model.evaluate(x_test_scaled,y_test)
# Out:
# 10000/10000 [==============================] - 1s 88us/sample - loss: 0.3435 - accuracy: 0.8887
# [0.3434687650322914, 0.8887]
